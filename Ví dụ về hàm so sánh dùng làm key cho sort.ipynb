# %%
import functools

lst = [list(range(i, i+5)) for i in range(5, 1, -1)]

def fitness(item):
    return item[0]+item[1]+item[2]+item[3]+item[4]
def compare(item1, item2):
    return fitness(item2) - fitness(item1)

sortedlist = sorted(lst, key=functools.cmp_to_key(compare))
print(sortedlist)
# Out:
# [[5, 6, 7, 8, 9], [4, 5, 6, 7, 8], [3, 4, 5, 6, 7], [2, 3, 4, 5, 6]]
